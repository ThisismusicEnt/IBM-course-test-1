# %% [markdown]
# <a href="https://colab.research.google.com/github/ThisismusicEnt/IBM-course-test-1/blob/main/Data_Science_Tools_and_Ecosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science Tools and Ecosystem
#
# ##In this notebook, Data Science Tools and Ecosystem are summarized.
#
# ### Some of the popular languages that Data Scientists use are:
#
#
#
# *   R
# *   Python
# *   C++
#
# ###Some of the commonly used libraries used by Data Scientists include:
#
# *   numpy
# *   pandas
# *   sklearn
# *   matplotlib

# %%
import numpy as np
import pandas as pd

menu = {
    'Data Science Tools': ['jupyter notebooks', 'googlecolab', 'vscode']}

df = pd.DataFrame(menu)
df
# Out:
#   Data Science Tools
# 0  jupyter notebooks
# 1        googlecolab
# 2             vscode

# %% [markdown]
# ###Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers
x = 3 * 4
y = x + 5
print(y)
# Out:
# 17

# %%
minutes = 200
hours = int(minutes/60)
print(f'200 minutes = {hours} hours')
# Out:
# 200 minutes = 3 hours

# %% [markdown]
# # **Objectives:**
#
#
# *    list popular languages for Data Science
# *    list popular IDEs and notebooks we use in data science
# *    using algorythims and python
# *    converting math into code to creat tables and statitical analysis

# %% [markdown]
# ##Auther
# Justin Puffpaff
